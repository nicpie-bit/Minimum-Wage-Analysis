# %%
import pandas as pd
import os
import csv
from sqlalchemy import create_engine 
from config import username, password, database

# %%
# The path to our CSV file
file = "Data/Minimum Wage Data.csv"

# Read data into pandas
df = pd.read_csv(file, encoding = "ISO-8859-1")
df.head()
# Out:
#    Year       State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 0  1968     Alabama             0.00000                             0.00
# 1  1968      Alaska             2.10000                            15.61
# 2  1968     Arizona             0.46800                             3.48
# 3  1968    Arkansas             0.15625                             1.16
# 4  1968  California             1.65000                            12.26
#
#    Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 0                  1.15                               8.55
# 1                  1.15                               8.55
# 2                  1.15                               8.55
# 3                  1.15                               8.55
# 4                  1.15                               8.55
#
#    Effective.Minimum.Wage  Effective.Minimum.Wage.2020.Dollars  CPI.Average  \
# 0                    1.15                                 8.55         34.8
# ...

# %%
# Removing unnecessary columns
cleaned_df = df[["Year", "State", "Effective.Minimum.Wage", "Federal.Minimum.Wage", "Federal.Minimum.Wage.2020.Dollars", "Effective.Minimum.Wage.2020.Dollars", "CPI.Average"]]
cleaned_df
# Out:
#       Year          State  Effective.Minimum.Wage  Federal.Minimum.Wage  \
# 0     1968        Alabama                    1.15                  1.15
# 1     1968         Alaska                    2.10                  1.15
# 2     1968        Arizona                    1.15                  1.15
# 3     1968       Arkansas                    1.15                  1.15
# 4     1968     California                    1.65                  1.15
# ...    ...            ...                     ...                   ...
# 2857  2020       Virginia                    7.25                  7.25
# 2858  2020     Washington                   13.50                  7.25
# 2859  2020  West Virginia                    8.75                  7.25
# 2860  2020      Wisconsin                    7.25                  7.25
# 2861  2020        Wyoming                    7.25                  7.25
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage.2020.Dollars  \
# ...

# %%
# Connect to local database 
engine = create_engine(f'postgresql://{username}:{password}@ec2-34-233-114-40.compute-1.amazonaws.com:5432/{database}')

# %%
# Load dataframe
cleaned_df.to_sql(name='wage', con=engine, if_exists='replace', index=False)

# %%
engine.table_names()
# Out:
# ['wage']

# %%
# Dataframe for
state_wage_df = cleaned_df[["Year", "State", "Effective.Minimum.Wage", "Effective.Minimum.Wage.2020.Dollars"]]
state_wage_df.head()
# Out:
#    Year       State  Effective.Minimum.Wage  \
# 0  1968     Alabama                    1.15
# 1  1968      Alaska                    2.10
# 2  1968     Arizona                    1.15
# 3  1968    Arkansas                    1.15
# 4  1968  California                    1.65
#
#    Effective.Minimum.Wage.2020.Dollars
# 0                                 8.55
# 1                                15.61
# 2                                 8.55
# 3                                 8.55
# 4                                12.26

# %%
state_vs_federal_2020_df = cleaned_df[["Year", "State", "Effective.Minimum.Wage.2020.Dollars", "Federal.Minimum.Wage.2020.Dollars"]]
state_vs_federal_2020_df.head()
# Out:
#    Year       State  Effective.Minimum.Wage.2020.Dollars  \
# 0  1968     Alabama                                 8.55
# 1  1968      Alaska                                15.61
# 2  1968     Arizona                                 8.55
# 3  1968    Arkansas                                 8.55
# 4  1968  California                                12.26
#
#    Federal.Minimum.Wage.2020.Dollars
# 0                               8.55
# 1                               8.55
# 2                               8.55
# 3                               8.55
# 4                               8.55

# %%
state_vs_federal_df = cleaned_df[["Year", "State", "Effective.Minimum.Wage", "Federal.Minimum.Wage"]]
state_vs_federal_df.head()
# Out:
#    Year       State  Effective.Minimum.Wage  Federal.Minimum.Wage
# 0  1968     Alabama                    1.15                  1.15
# 1  1968      Alaska                    2.10                  1.15
# 2  1968     Arizona                    1.15                  1.15
# 3  1968    Arkansas                    1.15                  1.15
# 4  1968  California                    1.65                  1.15
